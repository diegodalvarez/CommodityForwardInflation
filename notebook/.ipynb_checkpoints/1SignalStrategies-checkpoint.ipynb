# %% [markdown]
# # Energy Futures Inflation Measure Signal Strategies

# %% [markdown]
# This notebook will examine trading 5y5y forward inflation and Inflation Surprise Index using it as a signal.

# %%
import os
import pickle
import numpy as np
import pandas as pd
import seaborn as sns

import matplotlib.pyplot as plt
from   matplotlib.lines import Line2D
from   matplotlib.patches import Patch
from   matplotlib.ticker import FuncFormatter

import statsmodels.api as sm
from   statsmodels.regression.rolling import RollingOLS

# %%
repo_path  = os.path.abspath(os.path.join(os.getcwd(), ".."))
data_path  = os.path.join(repo_path, "data")
latex_path = os.path.join(repo_path, "writeup")
pic_path   = os.path.join(latex_path, "pictures")

# %%
sys.path.append(os.path.join(repo_path, "src"))
from FactorAnalysis import FactorModel

# %%
float_format = "{:,.2f}".format

# %%
repo_path = os.path.abspath(os.path.join(os.getcwd(), ".."))
pic_path  = os.path.join(repo_path, "writeup", "pictures")

# %% [markdown]
# # Regression between signal and returns

# %%
path = os.path.join(data_path, "FactorData", "InfSignalModels.pkl")
with open(path, "rb") as f: models = pickle.load(f)

# %% [markdown]
# Using perfect volatility targeted returns start by analyzing the z-score to the returns.

# %%
names = [
    name for name in list(models.keys())
    if name.split(" ")[1] == "perfect_hedge"]

df_param_raw = FactorModel().get_spef_model_params(models, names)

# %%
renamer0_ = {
    "expanding_regression": "Expanding"}

renamer1_ = {
    "forward_inf" : "5y5y",
    "surprise_inf": "Sur",
    "param_val"   : "Coeff",
    "pvalue"      : r"$p$-value",
    "tvalue"      : r"$t$-value",
    "out_sample"  : "Out-Sample",
    "in_sample"   : "In-Sample",
    "full_sample" : "Full Sample",
    "train_test"  : "Train/Test",
    "lagged"      : "Lagged",
    "perfect"     : "Perfect",
    "expanding"   : "Expanding",
    "resid"       : "OLS Residuals",
    "zscore"      : "Z-Score"}

_signal_renamer = {
    "OptimizedResid": "Optimized Residuals",
    "OptimizedZScore": "Optimized Z-Score"}

renamer = {**renamer0_, **renamer1_, **_signal_renamer}

# %%
display(df_param_raw
    .loc[lambda x: x.param == "z_score"]
    .drop(columns = ["param"])
    .assign(
        str_split    = lambda x: x.name.str.split(" "),
        ticker       = lambda x: x.str_split.str[0],
        vol_target   = lambda x: x.str_split.str[1],
        country      = lambda x: x.str_split.str[2],
        signal_group = lambda x: x.str_split.str[3],
        signal_lag   = lambda x: x.str_split.str[4])
    .drop(columns = ["name", "str_split", "vol_target"])
    .melt(id_vars = ["ticker", "country", "signal_group", "signal_lag"])
    .replace(renamer)
    .rename(columns = renamer)
    .rename(columns = {
        "ticker"      : "Ticker",
        "country"     : "Country",
        "signal_group": "Signal",
        "variable"    : "",
        "signal_lag"  : "Lag"})
    .replace({"lag_signal": "Lag", "signal": "No Lag"})
    .pivot(index = ["Ticker", "Country", "Signal"], columns = ["", "Lag"], values = "value"))
# Out:
#                           Coeff           $p$-value               $t$-value  \
# Lag                         Lag    No Lag       Lag        No Lag       Lag
# Ticker Country Signal
# CL1    UK      5y5y    0.000170  0.000563  0.074601  3.170893e-09  1.783272
#                Sur    -0.000110 -0.000012  0.350165  9.156864e-01 -0.934343
#        US      5y5y    0.000280  0.000568  0.003558  3.392303e-09  2.916300
#                Sur    -0.000142 -0.000124  0.138182  1.872431e-01 -1.482784
# CO1    UK      5y5y    0.000191  0.000544  0.043434  7.851087e-09  2.020000
#                Sur    -0.000171 -0.000050  0.146089  6.687309e-01 -1.453671
#        US      5y5y    0.000307  0.000559  0.001254  4.037682e-09  3.228036
#                Sur    -0.000109 -0.000082  0.245303  3.839255e-01 -1.161941
# HO1    UK      5y5y    0.000222  0.000566  0.018935  1.988489e-09  2.347544
#                Sur    -0.000226 -0.000098  0.053393  4.039944e-01 -1.932110
# ...

# %% [markdown]
# # Trading with Z-Scores

# %%
path        = os.path.join(data_path, "Backtests", "SignalBacktest.parquet")
df_backtest = (pd
    .read_parquet(path = path, engine = "pyarrow")
    .rename(columns = {"name": "tmp"}))

# %% [markdown]
# Below is a table of each individual strategy's sharpe

# %%
(df_backtest
    .drop(columns = ["date"])
    .groupby(["target", "inf_name", "country", "security"])
    ["vol_rtn"]
    .agg(lambda x: x.mean() / x.std() * np.sqrt(252))
    .to_frame(name = "sharpe")
    .reset_index()
    .replace(renamer)
    .assign(name = lambda x: x.country + " " + x.inf_name)
    .rename(columns = {
        "target"  : "",
        "name"    : "Inf Measure",
        "security": "Future"})
    .pivot(index = "Future", columns = ["", "Inf Measure"], values = "sharpe"))
# Out:
#                Lagged                                 Perfect            \
# Inf Measure   UK 5y5y   US 5y5y    UK Sur    US Sur   UK 5y5y   US 5y5y
# Future
# CL1          0.464029  0.779222  0.112619 -0.452558  0.436831  0.785300
# CO1          0.544441  0.694986  0.126601 -0.415246  0.533698  0.709624
# HO1          0.587000  0.710055 -0.026697 -0.367688  0.596077  0.690366
# NG1          0.189298  0.079502 -0.007847 -0.360067  0.203015  0.095905
# QS1          0.576625  0.871331  0.001987 -0.314695  0.587453  0.864465
# XB1          0.432273  0.685509 -0.152691 -0.417206  0.465138  0.689511
#
#
# Inf Measure    UK Sur    US Sur
# Future
# CL1          0.091349 -0.475999
# CO1          0.113295 -0.422464
# HO1         -0.024800 -0.410916
# NG1         -0.040560 -0.332222
# QS1          0.037732 -0.340532
# XB1         -0.153669 -0.434979

# %%
df_port = (df_backtest
    .drop(columns = ["security"])
    .groupby(["date", "target", "inf_name", "country"])
    .agg("mean")
    .reset_index())

# %% [markdown]
# Then calculate of equal weighting across all securities for each group

# %%
(df_port
    .drop(columns = ["date"])
    .replace(renamer)
    .assign(name = lambda x: x.country + " " + x.inf_name)
    [["name", "target", "vol_rtn"]]
    .groupby(["name", "target"])
    ["vol_rtn"]
    .agg(lambda x: x.mean() / x.std() * np.sqrt(252))
    .to_frame(name = "sharpe")
    .reset_index()
    .rename(columns = {
        "target": "",
        "name"  : "Inf Measure"})
    .pivot(index = "", columns = "Inf Measure", values = "sharpe"))
# Out:
# Inf Measure   UK 5y5y    UK Sur   US 5y5y    US Sur
#
# Lagged       0.562718  0.054267  0.789943 -0.455220
# Perfect      0.559756  0.047887  0.798893 -0.469622

# %%
title_renamer = {
    'US surprise_inf': "US Surprise Inf", 
    'UK surprise_inf': "UK Surprise Inf", 
    'UK forward_inf' : "UK 5y5y", 
    'US forward_inf' : "US 5y5y"}

# %%
targets   = df_port.target.drop_duplicates().sort_values().to_list()
fig, axes = plt.subplots(ncols = len(targets), figsize = (20,6))

for target, ax in zip(targets, axes.flatten()): 

    (df_port
        .loc[lambda x: x.target == target]
        .assign(name = lambda x: x.country + " " + x.inf_name)
        .replace(title_renamer)
        .rename(columns = {"name": ""})
        .pivot(index = "date", columns = "", values = "vol_rtn")
        .apply(lambda x: np.cumprod(1 + x))
        .plot(
            ax     = ax,
            logy   = True,
            title  = target.capitalize() + " Volatility Target",
            ylabel = "Cuml. Ret. Log-Scaled"))

fig.suptitle("Cumulative Returns of Trading Raw Z-Scores Equal Weighting\nUsing 10% Annualized Volatility Target")
plt.show()

# %%
path = os.path.join(data_path, "FactorData", "RawZScorePortTrendExposure.pkl")
with open(path, "rb") as f: models = pickle.load(f)

# %%
model_names   = [file for file in list(models.keys()) if file.split("+")[0] == "perfect"]
df_raw_params = FactorModel().get_spef_model_params(models, model_names)

# %%
corr_dict = {}
for model_name in model_names: 

    tmp_model = models[model_name]
    beta_sign = np.sign(tmp_model.params.iloc[0])
    rsquared  = tmp_model.rsquared
    corr_val  = beta_sign * np.sqrt(rsquared)
    
    corr_dict[model_name] = corr_val

# %%
df_corr = (pd.DataFrame.from_dict(
    data    = corr_dict,
    orient  = "index",
    columns = ["corr"])
    .reset_index()
    .rename(columns = {"index": "name"}))

# %%
benchmark_replace = {
    'Bloomberg Commodity Trend Index'    : "BBG Commod",
    'DB Cross Asset CTA Trend Index'     : "DB Cross-Asset",
    'SGI Commodity Trend Following Index': "SG Commod",
    'SG Trend Index'                     : "SG Trend"}

display(df_raw_params
    .loc[lambda x: x.param == "trend_rtn"]
    .assign(
        str_split  = lambda x: x.name.str.split("+"),
        signal     = lambda x: x.str_split.str[1],
        country    = lambda x: x.str_split.str[2],
        trend_name = lambda x: x.str_split.str[3])
    .merge(right = df_corr, how = "inner", on = ["name"])
    .replace(benchmark_replace)
    .drop(columns = ["name", "str_split", "param"])
    .melt(id_vars = ["signal", "country", "trend_name", "corr"])
    .replace({
        "forward_inf" : "5y5y",
        "surprise_inf": "Sur"})
    .rename(columns = {
        "variable"  : "",
        "trend_name": "Trend Idx",
        "country"   : "Country",
        "corr"      : "Corr"})
    .pivot(index = ["signal", "Country", "Trend Idx", "Corr"], columns = "", values = "value")
    .reset_index()
    .melt(id_vars = ["signal", "Country", "Trend Idx"])
    .assign(name = lambda x: x.signal + " " + x.Country)
    .pivot(index = ["Trend Idx", "name"], columns = "", values = "value")
    .rename(columns = {
        "param_val": "Coeff",
        "pvalue"   : "$p$-value",
        "tvalue"   : "$t$-stat"}))
# Out:
#                             Corr     Coeff     $p$-value  $t$-stat
# Trend Idx      name
# BBG Commod     5y5y UK  0.027117  0.064727  4.871336e-02  1.971548
#                5y5y US  0.014477  0.034551  2.989820e-01  1.038724
#                Sur UK   0.021757 -0.053160  8.809550e-02 -1.705802
#                Sur US  -0.117303 -0.288712  5.330810e-21 -9.435481
# DB Cross-Asset 5y5y UK  0.008222  0.012418  5.592014e-01  0.584067
#                5y5y US  0.000346 -0.000524  9.806222e-01 -0.024290
#                Sur UK   0.035674 -0.053541  6.252951e-03 -2.735201
#                Sur US  -0.037634 -0.056557  3.300018e-03 -2.939477
# SG Commod      5y5y UK  0.019254  0.015021  1.746492e-01  1.357610
#                5y5y US  0.019070  0.014979  1.842764e-01  1.327892
#                Sur UK  -0.006837  0.005326  6.032746e-01  0.519726
#                Sur US  -0.099644 -0.078154  9.171787e-15 -7.769938
# SG Trend       5y5y UK  0.010053 -0.006891  4.650176e-01 -0.730663
# ...

# %% [markdown]
# # Trading Residuals

# %%
path = os.path.join(data_path, "Backtests", "OLSResidualBacktest.parquet")
df_port = (pd
    .read_parquet(path = path, engine = "pyarrow")
    .loc[lambda x: (x.regression == "full_sample") & (x.target == "perfect")]
    [["date", "country", "signal_name", "vol_rtn"]]
    .groupby(["date", "country", "signal_name"])
    .agg("mean")
    .reset_index())

# %% [markdown]
# Trading the residuals resulted in weak portfolios

# %%
display(df_port
    .drop(columns = ["date"])
    .groupby(["country", "signal_name"])
    .agg(lambda x: x.mean() / x.std() * np.sqrt(252))
    .reset_index()
    .replace(renamer)
    .rename(columns = {"signal_name": ""})
    .pivot(index = "country", columns = "", values = "vol_rtn"))
# Out:
#              5y5y       Sur
# country
# UK       0.108933  0.131959
# US       0.138388  0.047914

# %%
fig, axes = plt.subplots(figsize = (8,5))

(df_port
    .replace(renamer)
    .assign(combined = lambda x: x.country + " " + x.signal_name)
    .rename(columns = {"combined": ""})
    .pivot(index = "date", columns = "", values = "vol_rtn")
    .apply(lambda x: np.cumprod(1 + x))
    .plot(
        ax     = axes,
        logy   = True,
        title  = "Cumulative Returns of Perfectly Volatility Targeted OLS Residuals\nFull Sample In-Sample",
        ylabel = "Cuml. Ret. Log-Scaled"))

plt.show()

# %% [markdown]
# # Trading Forecasted Values

# %%
path             = os.path.join(data_path, "Backtests", "OLSPredBacktest.parquet")
df_pred_backtest = (pd
    .read_parquet(path = path, engine = "pyarrow")
    .drop(columns = ["y_pred", "fut_rtn", "group", "name", "signal_rtn"]))

# %%
display(df_pred_backtest
    .drop(columns = ["date"])
    .groupby(["target", "security", "country", "regression", "sample_group", "signal_name"])
    .agg(lambda x: x.mean() / x.std() * np.sqrt(252))
    .reset_index()
    .replace(renamer)
    .rename(columns = {
        "regression"  : "Regression",
        "sample_group": "Sample",
        "target"      : "Vol. Target",
        "security"    : "Fut",
        "signal_name" : "Signal",
        "country"     : "Country"})
    .pivot(index = ["Fut", "Signal", "Country"], columns = ["Vol. Target", "Sample", "Regression"], values = "vol_rtn"))
# Out:
# Vol. Target            Lagged                                      Perfect  \
# Sample             Out-Sample   In-Sample            Out-Sample Out-Sample
# Regression          Expanding Full Sample Train/Test Train/Test  Expanding
# Fut Signal Country
# CL1 5y5y   UK        0.574919    0.439375   0.489662   0.171149   0.575265
#            US        0.708135    0.602826   0.437907   0.392789   0.727508
#     Sur    UK        0.364779    0.227866   0.001519   0.367722   0.404402
#            US        0.156603    0.129695   0.055653   0.316546   0.209515
# CO1 5y5y   UK        0.493300    0.378810   0.701562   0.106915   0.521965
#            US        0.846750    0.797956   0.732913   0.592087   0.861213
#     Sur    UK        0.411637    0.364515   0.247682   0.655382   0.461131
#            US        0.350167    0.286125   0.250722   0.318059   0.410432
# HO1 5y5y   UK        0.480372    0.452174   0.762149   0.042201   0.524201
# ...

# %%
df_pred_port = (df_pred_backtest
    .drop(columns = ["security", "sample_group"])
    .groupby(["date", "target", "country", "regression", "signal_name"])
    .agg("mean")
    .reset_index())

# %%
df_sample_namer = (df_pred_backtest
    .loc[lambda x: x.regression == "train_test"]
    [["sample_group", "date"]]
    .drop_duplicates())

# %%
df_perf_port = df_pred_port.loc[lambda x: x.target == "perfect"]
group_vars   = df_perf_port.regression.drop_duplicates().sort_values().to_list()
fig, axes    = plt.subplots(ncols = len(group_vars), figsize = (25,6))

colorer = {
    "in_sample" : "tab:blue",
    "out_sample": "tab:green"}

legend_handles = [
    Patch(
        facecolor=colorer[key],
        label=renamer[key]
    )
    for key in colorer]


for group_var, ax in zip(group_vars, axes.flatten()): 

    if group_var != "train_test":
        
        (df_perf_port
            .loc[lambda x: x.regression == group_var]
            .replace(renamer)
            .assign(name = lambda x: x.country + " " + x.signal_name)
            .rename(columns = {"name": ""})
            .pivot(index = "date", columns = "", values = "vol_rtn")
            .assign(Avg = lambda x: x.mean(axis = 1))
            .apply(lambda x: np.cumprod(1 + x))
            .plot(
                logy  = True,
                ax    = ax,
                title = renamer[group_var]))

    else:
        
        df_tmp = (df_perf_port
            .loc[lambda x: x.regression == group_var]
            .replace(renamer)
            .assign(name = lambda x: x.country + " " + x.signal_name)
            .pivot(index = "date", columns = "name", values = "vol_rtn")
            .apply(lambda x: np.cumprod(1 + x))
            .merge(right = df_sample_namer, how = "inner", on = ["date"])
            .set_index("date"))

        groups = df_tmp.sample_group.drop_duplicates().sort_values().to_list()
        for sample_group in groups: 

            (df_tmp
                .loc[lambda x: x.sample_group == sample_group]
                .drop(columns = ["sample_group"])
                .plot(
                    logy   = True,
                    ax     = ax,
                    color  = colorer[sample_group],
                    legend = False))

        ax.set_title(renamer[group_var])
        ax.legend(handles = legend_handles)
    ax.set_ylabel("Cuml. Ret. Log-Scaled")

fig.suptitle(r"Cumulative Returns of Trading Forecasted Returns using Full-Sample Model, Train/Test Model, and Expanding Out-of-Sample" + "\n10% Annualized Volatility Target Equal Weighting, Hedged contemporaneously\n")
out_path = os.path.join(pic_path, "ForecastedReturnResults.jpeg")
fig.savefig(out_path)
plt.show()

# %%
dates             = df_sample_namer.loc[lambda x: x.sample_group == "out_sample"].date.to_list()
df_sharpe_compare = (df_pred_backtest
    .loc[lambda x: x.date.isin(dates)]
    .drop(columns = ["date", "sample_group"])
    .groupby(["target", "country", "regression", "signal_name", "security"])
    .agg(lambda x: x.mean() / x.std() * np.sqrt(252))
    .reset_index())

# %%
display(df_pred_backtest
    .drop(columns = ["sample_group", "security"])
    .groupby(["date", "target", "country", "regression", "signal_name"])
    .agg("mean")
    .reset_index()
    .drop(columns = ["date"])
    .groupby(["target", "country", "regression", "signal_name"])
    .agg(lambda x: x.mean() / x.std() * np.sqrt(252))
    .reset_index()
    .replace(renamer)
    .rename(columns = {
        "signal_name": "Signal",
        "country"    : "Country",
        "target"     : "",
        "regression" : "Regression"})
    .pivot(index = ["Signal", "Country"], columns = ["", "Regression"], values = "vol_rtn"))
# Out:
#                   Lagged                          Perfect              \
# Regression     Expanding Full Sample Train/Test Expanding Full Sample
# Signal Country
# 5y5y   UK       0.698544    0.525971   0.655015  0.739126    0.540544
#        US       0.990861    0.929881   0.773184  1.005960    0.943277
# Sur    UK       0.605650    0.454134   0.411787  0.647112    0.488420
#        US       0.450708    0.367613   0.402523  0.497812    0.412295
#
#
# Regression     Train/Test
# Signal Country
# 5y5y   UK        0.660339
#        US        0.802042
# Sur    UK        0.443182
#        US        0.442384

# %%
(df_sharpe_compare
    .pivot(index = ["target", "country", "signal_name", "security"], columns = "regression", values = "vol_rtn")
    .assign(
        train_test_loss = lambda x: x.train_test - x.full_sample,
        expanding_loss  = lambda x: x.expanding_regression  - x.full_sample)
    .drop(columns = ["expanding_regression", "full_sample", "train_test"])
    .reset_index()
    .melt(id_vars = ["target", "country", "signal_name", "security"])
    .replace(renamer)
    .replace({
        "train_test_loss": "Train/Test Loss",
        "expanding_loss" : "Expanding Loss"})
    .rename(columns = {
        "security"   : "Fut",
        "country"    : "Country",
        "signal_name": "Signal",
        "target"     : "Vol. Target",
        "regression" : "Regression"})
    .pivot(index = ["Fut", "Country", "Signal"], columns = ["Regression", "Vol. Target"], values = "value"))
# Out:
# Regression         Train/Test Loss           Expanding Loss
# Vol. Target                 Lagged   Perfect         Lagged   Perfect
# Fut Country Signal
# CL1 UK      5y5y         -0.328297 -0.359913      -0.124282 -0.134379
#             Sur          -0.235298 -0.252924       0.133530  0.124028
#     US      5y5y         -0.309447 -0.320072       0.040021  0.042930
#             Sur           0.004373  0.004638      -0.097232 -0.100826
# CO1 UK      5y5y         -0.104843 -0.154433       0.114937  0.094113
#             Sur           0.011568  0.012396      -0.030307 -0.032910
#     US      5y5y         -0.164975 -0.182923       0.142665  0.151697
#             Sur          -0.166600 -0.177144       0.091698  0.099407
# HO1 UK      5y5y         -0.364959 -0.232661      -0.202556 -0.054296
#             Sur           0.003642  0.003535       0.029569  0.030740
#     US      5y5y         -0.208086 -0.213395       0.157374  0.156513
# ...

# %%
df_port = (df_pred_backtest
    .drop(columns = ["security", "country", "sample_group", "signal_name"])
    .groupby(["date", "target", "regression"])
    .agg("mean")
    .reset_index())

# %%
groups    = df_port.target.drop_duplicates().sort_values().to_list()
fig, axes = plt.subplots(ncols = len(groups), figsize = (20,6))

for group, ax in zip(groups, axes.flatten()): 

    (df_port
        [lambda x: x.target == group]
        .rename(columns = {"regression": ""})
        .pivot(index = "date", columns = "", values = "vol_rtn")
        .rename(columns = renamer)
        .dropna()
        .apply(lambda x: np.cumprod(1 + x))
        .plot(
            ax     = ax,
            logy   = True,
            ylabel = "Cuml. Ret. Log-Scaled",
            title  = renamer[group] + " Hedging"))

fig.suptitle("Cumulative Returns of Trading Forecasted Returns Equal Weighting Across Portfolios")
plt.show()

# %%
(df_port
    .drop(columns = ["date"])
    .groupby(["target", "regression"])
    .agg(lambda x: x.mean() / x.std() * np.sqrt(252))
    .reset_index()
    .replace(renamer)
    .rename(columns = {
        "regression": "",
        "target"    : "Vol. Target"})
    .pivot(index = "", columns = "Vol. Target", values = "vol_rtn"))
# Out:
# Vol. Target    Lagged   Perfect
#
# Expanding    0.955624  1.010328
# Full Sample  0.771896  0.812456
# Train/Test   0.845305  0.878710

# %% [markdown]
# # Optimized Signals

# %%
opt_path  = os.path.join(data_path, "Backtests")
opt_paths = ([
    os.path.join(opt_path, file) for file in os.listdir(opt_path)
    if file[0:3] == "Opt"])

# %% [markdown]
# df_opt = (pd
#     .concat([pd.read_parquet(path = file, engine = "pyarrow").assign(name = file) for file in opt_paths])
#     .assign(name = lambda x: x.name.str.split("\\").str[-1].str.split(".").str[0]))

# %%
df_opt = (pd.concat([
    pd.read_parquet(path = file, engine = "pyarrow").assign(name =  file.split("\\")[-1].split(".")[0]) 
    for file in opt_paths]))

# %%
df_opt_port = (df_opt
    .drop(columns = [
        "resid", "decile", "lag_decile", "decile_group", "opt_date",
        "signal_name", "z_score", "sharpe", "signal_scaler", "group_var", "rtn"])
    .melt(id_vars = ["date", "country", "group", "security", "optimization", "sample_group", "name", "signal_rtn"])
    .dropna()
    .assign(
        value   = lambda x: np.where(np.abs(x.value) == np.inf, np.nan, x.value),
        vol_rtn = lambda x: x.value * x.signal_rtn)
    .assign(vol_rtn = lambda x: np.where(np.abs(x.vol_rtn) > 0.1, np.nan, x.vol_rtn))
    .loc[lambda x: x.optimization != "expanding"]
    .drop(columns = ["security", "signal_rtn", "value"])
    .groupby(["date", "country", "group", "optimization", "sample_group", "name", "variable"])
    .agg("mean")
    .reset_index())

# %%
df_tmp_port = (df_opt_port
    .loc[lambda x: x.optimization == "full_sample"]
    .loc[lambda x: x.variable == "weight"]
    .drop(columns = ["optimization", "sample_group"]))

groups    = df_tmp_port.name.drop_duplicates().sort_values().to_list()
fig, axes = plt.subplots(ncols = len(groups), figsize = (20,6)) 

for group, ax in zip(groups, axes.flatten()): 

    (df_tmp_port
        .loc[lambda x: x.name == group]
        .replace(renamer)
        .assign(name = lambda x: x.country + " " + x.group)
        .rename(columns = {"name": ""})
        .pivot(index = "date", columns = "", values = "vol_rtn")
        .apply(lambda x: np.cumprod(1 + x))
        .ffill()
        .plot(
            ax     = ax,
            logy   = True,
            ylabel = "Cuml. Ret. Log-Scaled",
            title  = renamer[group],
            xlabel = ""))

fig.suptitle("Cumulative Returns of Full-Sample/In-Sample Deciled Optimized Strategies\n10% Annualized Volatility Target Hedged Contemporaneously\n")
plt.show()

# %%
(df_tmp_port
    .assign(tmp = lambda x: x.country + " " + x.group)
    .pivot(index = ["date", "name"], columns = "tmp", values = "vol_rtn")
    .reset_index()
    .melt(id_vars = ["date", "name"])
    .rename(columns = {"value": "adj_val"})
    .assign(raw_val = lambda x: np.where(x.adj_val != x.adj_val, 0, x.adj_val))
    .melt(id_vars = ["date", "name", "tmp"])
    .dropna()
    .drop(columns = ["date"])
    .groupby(["name", "tmp", "variable"])
    .agg(lambda x: x.mean() / x.std() * np.sqrt(252))
    .reset_index()
    .assign(
        country = lambda x: x.tmp.str.split(" ").str[0],
        signal  = lambda x: x.tmp.str.split(" ").str[1])
    .replace(renamer)
    .replace({
        "adj_val": "Adjusted",
        "raw_val": "Raw"})
    .rename(columns = {
        "country" : "Country",
        "signal"  : "Signal",
        "variable": "Sharpe",
        "name"    : ""})
    .pivot(index = ["Country", "Signal"], columns = ["", "Sharpe"], values = "value"))
# Out:
#                Optimized Residuals           Optimized Z-Score
# Sharpe                    Adjusted       Raw          Adjusted       Raw
# Country Signal
# UK      5y5y              0.512132  0.441479          0.685015  0.438196
#         Sur               0.481418  0.447558          0.618750  0.425262
# US      5y5y              0.538600  0.478839          1.420889  0.899872
#         Sur               0.490338  0.465900          0.705934  0.499168

# %%
df_avg = (df_tmp_port
    .drop(columns = ["country", "group", "variable"])
    .groupby(["date", "name"])
    .agg("mean")
    .reset_index()
    .rename(columns = {"name": ""})
    .pivot(index = "date", columns = "", values = "vol_rtn")
    .fillna(0)
    .assign(avg_rtn = lambda x: x.mean(axis = 1))
    .rename(columns = {"avg_rtn": "Average"}))

# %%
fig, axes = plt.subplots(figsize = (9,6))

(df_avg
    .apply(lambda x: np.cumprod(1 + x))
    .rename(columns = renamer)
    .plot(
        ax   = axes,
        logy = True,
        ylabel = "Cuml. Ret. Log-Scaled",
        title  = "Cumulative Returns of Equal Weight Returns across Optimized Full Sample/In Sample\n10% Volatility Target Hedged Contemporaneously"))

plt.show()

# %%
df_sample_port = (df_opt_port
    .loc[lambda x: x.variable == "weight"]
    [["date", "optimization", "name", "vol_rtn"]]
    .groupby(["date", "optimization", "name"])
    .agg("mean")
    .reset_index())

# %%
groups    = df_sample_port.name.drop_duplicates().sort_values().to_list()
fig, axes = plt.subplots(ncols = len(groups), figsize = (20,6))

for group, ax in zip(groups, axes.flatten()): 

    (df_sample_port
        .loc[lambda x: x.name == group]
        .replace(renamer)
        .rename(columns = {"optimization": ""})
        .pivot(index = "date", columns = "", values = "vol_rtn")
        .apply(lambda x: np.cumprod(1 + x))
        .plot(
            logy   = True,
            ax     = ax,
            title  = renamer[group],
            ylabel = "Cuml. Ret. Log-Scaled",
            xlabel = ""))

fig.suptitle(r"Cumulative Returns of Decile Optimized Strategy Train/Test (2018 Cutoff) Equal Weighting" + "\n10% Annualized Volatility Target Hedged Contemporaneousnly\n")
plt.show()

# %%
(df_sample_port
    .pivot(index = ["date", "optimization"], columns = "name", values = "vol_rtn")
    .assign(avg_rtn = lambda x: x.mean(axis = 1))
    .reset_index()
    .melt(id_vars = ["date", "optimization"], value_name = "adj_val")
    .assign(raw_val = lambda x: np.where(x.adj_val != x.adj_val, 0, x.adj_val))
    .melt(id_vars = ["date", "optimization", "name"])
    .dropna()
    .drop(columns = ["date"])
    .groupby(["optimization", "name", "variable"])
    .agg(lambda x: x.mean() / x.std() * np.sqrt(252))
    .reset_index()
    .replace(renamer)
    .replace({
        "avg_rtn": "Avg",
        "adj_val": "Adj",
        "raw_val": "Raw"})
    .rename(columns = {
        "name"        : "Name",
        "variable"    : "Sharpe",
        "optimization": ""})
    .pivot(index = "Name", columns = ["", "Sharpe"], values = "value"))
# Out:
#                     Full Sample           Train/Test
# Sharpe                      Adj       Raw        Adj       Raw
# Name
# Avg                    0.655120  0.655120   0.774265  0.774265
# Optimized Residuals    0.538865  0.473666   0.778953  0.776946
# Optimized Z-Score      0.819748  0.753949   0.701588  0.697769

# %%
(df_opt_port
    [["date", "optimization", "name", "variable", "vol_rtn"]]
    .groupby(["date", "optimization", "name", "variable"])
    .agg("mean")
    .reset_index()
    .pivot(index = ["date", "optimization", "variable"], columns = "name", values = "vol_rtn")
    .assign(avg = lambda x: x.mean(axis = 1))
    .reset_index()
    .melt(id_vars = ["date", "optimization", "variable"])
    .drop(columns = ["date"])
    .dropna()
    .groupby(["optimization", "variable", "name"])
    .agg(lambda x: x.mean() / x.std() * np.sqrt(252))
    .reset_index()
    .replace(renamer)
    .replace({
        "avg"       : "Avg",
        "lag_weight": "Lagged",
        "weight"    : "Perfect"})
    .rename(columns = {
        "optimization": "Sample Group",
        "name"        : "Signal",
        "variable"    : "Hedging"})
    .pivot(index = ["Sample Group", "Signal"], columns = "Hedging", values = "value"))
# Out:
# Hedging                             Lagged   Perfect
# Sample Group Signal
# Full Sample  Avg                  0.542153  0.655120
#              Optimized Residuals  0.444611  0.538865
#              Optimized Z-Score    0.747604  0.819748
# Train/Test   Avg                  0.663632  0.774265
#              Optimized Residuals  0.670346  0.778953
#              Optimized Z-Score    0.629791  0.701588

# %%
df_avg_opt_port = (df_opt_port
    [["date", "optimization", "variable", "vol_rtn"]]
    .groupby(["date", "optimization", "variable"])
    .agg("mean")
    .reset_index()
    .replace({
        "lag_weight": "lagged",
        "weight"    : "perfect"})
    .rename(columns = {
        "optimization": "sample_group",
        "vol_rtn"     : "opt_rtn",
        "variable"    : "target"}))

# %%
df_avg_opt_port.head(3)
# Out:
#         date sample_group   target   opt_rtn
# 0 2000-01-06  full_sample   lagged -0.000862
# 1 2000-01-06  full_sample  perfect -0.000870
# 2 2000-01-06   train_test   lagged  0.000537

# %%
df_regress_port = (df_port
    .rename(columns = {"regression": "sample_group"})
    .loc[lambda x: x.sample_group != "expanding_regression"]
    .rename(columns = {"vol_rtn": "regress_rtn"}))

# %%
df_combined = (df_avg_opt_port
    .merge(right = df_regress_port, how = "inner", on = ["date", "sample_group", "target"])
    .set_index("date"))

# %%
(df_combined
    .reset_index(drop = True)
    .groupby(["sample_group", "target"])
    .agg("corr")
    .loc[lambda x: x.regress_rtn != 1]
    .reset_index()
    .drop(columns = ["opt_rtn", "level_2"])
    .replace(renamer)
    .rename(columns = {
        "target"      : "",
        "sample_group": "Sample Group"})
    .pivot(index = "Sample Group", columns = "", values = "regress_rtn"))
# Out:
#                 Lagged   Perfect
# Sample Group
# Full Sample   0.326280  0.301623
# Train/Test    0.506625  0.514915

# %%
(df_combined
    .reset_index()
    .set_index(["date", "sample_group", "target"])
    .assign(avg_rtn = lambda x: x.mean(axis = 1))
    .reset_index()
    .melt(id_vars = ["date", "sample_group", "target"])
    .drop(columns = ["date"])
    .groupby(["sample_group", "target", "variable"])
    .agg(lambda x: x.mean() / x.std() * np.sqrt(252))
    .reset_index()
    .replace(renamer)
    .replace({
        "avg_rtn"    : "Avg",
        "opt_rtn"    : "Optimized",
        "regress_rtn": "Forecasted"})
    .rename(columns = {
        "sample_group": "Sample",
        "target"      : "Target",
        "variable"    : "Strategy"})
    .pivot(index = ["Sample", "Target"], columns = "Strategy", values = "value"))
# Out:
# Strategy                  Avg  Forecasted  Optimized
# Sample      Target
# Full Sample Lagged   0.708236    0.703339   0.490033
#             Perfect  0.821952    0.747620   0.597949
# Train/Test  Lagged   0.844100    0.844651   0.663421
#             Perfect  0.931056    0.865593   0.778764
